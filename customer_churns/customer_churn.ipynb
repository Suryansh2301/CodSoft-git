# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\india\\Downloads\\Churn_Modelling.csv")

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
df['Surname'].unique()
# Out:
# array(['Hargrave', 'Hill', 'Onio', ..., 'Kashiwagi', 'Aldridge',
#        'Burbidge'], shape=(2932,), dtype=object)

# %%
surname_counts = df['Surname'].value_counts()
df["surname_freq"] = df['Surname'].map(surname_counts)

# %%
df["surname_freq"].unique()
# Out:
# array([ 1, 17,  8, 14, 20, 22,  4,  2, 18, 19,  6,  5, 16, 29, 12, 13, 24,
#        11,  9, 15, 10,  3,  7, 23, 21, 25, 32, 26, 28])

# %%
len(df["Surname"].unique())
# Out:
# 2932

# %%
df[["EstimatedSalary"]].boxplot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.figure(figsize =(10,10))

# sns.barplot(df["Balance_scaleds"].head(50))
# plt.show()

# %%
plt.figure(figsize=(17, 5))
sns.countplot(data=df, y=df["Geography"], palette='hls')
plt.title('Count of category')
plt.xlabel('Count')
plt.ylabel('category')
plt.show()
# Out:
# C:\Users\india\AppData\Local\Temp\ipykernel_11008\3220691971.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=df["Geography"], palette='hls')

# %% [markdown]
# Transformation

# %%
from sklearn.preprocessing import LabelEncoder 

encode = LabelEncoder()

df[["Geography_encode","Gender_encode"]]= df[["Geography","Gender"]].apply(encode.fit_transform)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  surname_freq  Geography_encode  Gender_encode
# 0        101348.88       1             1                 0              0
# ...

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

std_scaler = StandardScaler()
# scaler = MinMaxScaler()

# %%
scaled = std_scaler.fit_transform(df[["Balance","EstimatedSalary"]])
# scaled_value = scaler.fit_transform(df[["Balance","EstimatedSalary"]])

df[["Balance_scaled","EstimatedSalary_scaled"]] = pd.DataFrame(scaled, columns=["Balance_scaled","EstimatedSalary_scaled"])
# df[["Balance_scaleds","EstimatedSalary_scaleds"]] = pd.DataFrame(scaled_value, columns=["Balance_scaled","EstimatedSalary_scaled"])

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  surname_freq  Geography_encode  Gender_encode  \
# 0        101348.88       1             1                 0              0
# ...

# %%
df.drop(columns=["RowNumber"], inplace =True)

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  surname_freq  Geography_encode  Gender_encode  Balance_scaled  \
# ...

# %%
plt.figure(figsize=(17, 5))
sns.countplot(data=df, y=df["surname_freq"], palette='hls')
plt.title('Count of category')
plt.xlabel('Count')
plt.ylabel('category')
plt.show()
# Out:
# C:\Users\india\AppData\Local\Temp\ipykernel_11008\3507241676.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y=df["surname_freq"], palette='hls')

# %%
df.shape
# Out:
# (10000, 18)

# %%
data = df[["CreditScore","Age","Tenure","NumOfProducts","HasCrCard","IsActiveMember","Exited","Geography_encode","Gender_encode","Balance_scaled","EstimatedSalary_scaled"]]

# %%
data.shape
# Out:
# (10000, 11)

# %%
x= data.drop(columns=["Exited"])
y = data["Exited"]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size =0.2, random_state =42)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(x_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(verbose =1,n_jobs=-1,class_weight='balanced')

# %%
lr.fit(X_res, y_res)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# LogisticRegression(class_weight='balanced', n_jobs=-1, verbose=1)

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, roc_auc_score, accuracy_score, f1_score,classification_report

# %%
print("model ---> LogisticRegression")

print("confusion matrix: \n", confusion_matrix(y_test, y_pred))
print(".."*30)
print("precision: ", precision_score(y_test, y_pred))
print(".."*30)
print("recall:  ", recall_score(y_test, y_pred))
print(".."*30)
print("f1_score:  ", f1_score(y_test, y_pred))
print(".."*30)
print("roc_auc_score: ", roc_auc_score(y_test, y_pred))
print(".."*30)
print("accuracy_score: ", accuracy_score(y_test, y_pred))
print(".."*30)
print("classification_reporte:\n ", classification_report(y_test, y_pred))
# Out:
# model ---> LogisticRegression
# confusion matrix:
#  [[1226  381]
#  [ 170  223]]
# ............................................................
# precision:  0.36920529801324503
# ............................................................
# recall:   0.5674300254452926
# ............................................................
# f1_score:   0.4473420260782347
# ............................................................
# roc_auc_score:  0.6651711421563737
# ............................................................
# accuracy_score:  0.7245
# ............................................................
# classification_reporte:
#                 precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82      1607
#            1       0.37      0.57      0.45       393
#
#     accuracy                           0.72      2000
#    macro avg       0.62      0.67      0.63      2000
# weighted avg       0.78      0.72      0.74      2000

# %%
from xgboost import XGBClassifier

# models = XGBClassifier(learning_rate = 0.2, max_depth= 9, n_estimators=200, scale_pos_weight=3)  # or appropriate weight
models = XGBClassifier(learning_rate = 0.2, max_depth= 9, n_estimators=100, scale_pos_weight=1)  # or appropriate weight for precision
# models = XGBClassifier(learning_rate = 0.01, max_depth= 3, n_estimators=100, scale_pos_weight=3)  # or appropriate weight for recall
models.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.2, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=9,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred1 = models.predict(x_test)

# %%
# y_proba = model.predict_proba(x_test)[:, 1]
# y_pred_new = (y_proba >= 0.3).astype(int)

# %%
print("model ---> XGBClassifier")

print("confusion matrix: \n", confusion_matrix(y_test, y_pred1))
print(".."*30)
print("precision: ", precision_score(y_test, y_pred1))
print(".."*30)
print("recall:  ", recall_score(y_test, y_pred1))
print(".."*30)
print("f1_score:  ", f1_score(y_test, y_pred1))
print(".."*30)
print("roc_auc_score: ", roc_auc_score(y_test, y_pred1))
print(".."*30)
print("accuracy_score: ", accuracy_score(y_test, y_pred1))
print(".."*30)
print("classification_reporte:\n ", classification_report(y_test, y_pred1))
# Out:
# model ---> XGBClassifier
# confusion matrix:
#  [[1527   80]
#  [ 194  199]]
# ............................................................
# precision:  0.7132616487455197
# ............................................................
# recall:   0.5063613231552163
# ............................................................
# f1_score:   0.5922619047619048
# ............................................................
# roc_auc_score:  0.7282895601463698
# ............................................................
# accuracy_score:  0.863
# ............................................................
# classification_reporte:
#                 precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      1607
#            1       0.71      0.51      0.59       393
#
#     accuracy                           0.86      2000
#    macro avg       0.80      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_test, y_pred1)

# Plot and choose a threshold manually
import matplotlib.pyplot as plt
plt.plot(thresholds, precision[:-1], label='Precision')
plt.plot(thresholds, recall[:-1], label='Recall')
plt.xlabel('Threshold')
plt.legend()
plt.show()

# Apply new threshold
new_threshold = 0.3
y_pred_adjusted = (y_pred1 >= new_threshold).astype(int)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(x, y)

# %%
# from sklearn.model_selection import GridSearchCV

# params = {
#     'n_estimators': [100, 200],
#     'max_depth': [3, 6, 9],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'scale_pos_weight': [1, 2, 3]  # useful for imbalance
# }

# grid = GridSearchCV(XGBClassifier(), param_grid=params, scoring= "precision", cv=5)
# grid.fit(X_resampled, y_resampled)
# print("best recall: ", grid.best_score_)
# print("params recall: ", grid.best_params_)

# %%
from sklearn.ensemble import RandomForestClassifier

# rfc = RandomForestClassifier(class_weight="balanced")
# rfc = RandomForestClassifier(class_weight= 'balanced', max_depth=10, min_samples_split=5, n_estimators=200)
# rfc = RandomForestClassifier(class_weight= 'balanced', max_depth=20, min_samples_split=2, n_estimators=200) # for precision
rfc = RandomForestClassifier(class_weight= "balanced_subsample", max_depth=5, min_samples_split=5, n_estimators=200,oob_score= True,criterion ="entropy") # for recall
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced_subsample', criterion='entropy',
#                        max_depth=5, min_samples_split=5, n_estimators=200,
#                        oob_score=True)

# %%
y_pred3 = rfc.predict(x_test)

# %%
print("model ---> RandomForestClassifier")

print("confusion matrix: \n", confusion_matrix(y_test, y_pred3))
print(".."*30)
print("precision: ", precision_score(y_test, y_pred3))
print(".."*30)
print("recall:  ", recall_score(y_test, y_pred3))
print(".."*30)
print("f1_score:  ", f1_score(y_test, y_pred3))
print(".."*30)
print("roc_auc_score: ", roc_auc_score(y_test, y_pred3))
print(".."*30)
print("accuracy_score: ", accuracy_score(y_test, y_pred3))
print(".."*30)
print("classification_reporte:\n ", classification_report(y_test, y_pred3))
# Out:
# model ---> RandomForestClassifier
# confusion matrix:
#  [[1288  319]
#  [  99  294]]
# ............................................................
# precision:  0.4796084828711256
# ............................................................
# recall:   0.7480916030534351
# ............................................................
# f1_score:   0.584493041749503
# ............................................................
# roc_auc_score:  0.7747925345696548
# ............................................................
# accuracy_score:  0.791
# ............................................................
# classification_reporte:
#                 precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1607
#            1       0.48      0.75      0.58       393
#
#     accuracy                           0.79      2000
#    macro avg       0.70      0.77      0.72      2000
# weighted avg       0.84      0.79      0.81      2000

# %%
from sklearn.metrics import precision_score, recall_score

y_prob = rfc.predict_proba(x_test)[:,1]
threshold = 0.6 # try 0.55, 0.6, 0.65, etc.
y_pred = (y_prob >= threshold).astype(int)

print("Precision:", precision_score(y_test, y_pred3))
print("Recall:", recall_score(y_test, y_pred3))
print()
print("Precision:", precision_score(y_test, y_pred1))
print("Recall:", recall_score(y_test, y_pred1))
# Out:
# Precision: 0.4796084828711256
# Recall: 0.7480916030534351
#
# Precision: 0.7132616487455197
# Recall: 0.5063613231552163

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators': [200, 300],
    'max_depth': [8, 12],
    'min_samples_split': [5, 10],
    'min_samples_leaf': [2, 4],
    'class_weight': ['balanced', 'balanced_subsample']
}

grid = GridSearchCV(RandomForestClassifier(), param_grid=params, scoring="precision", cv=5)
grid.fit(X_resampled, y_resampled)
print("Best Precision:", grid.best_score_)
print("Best Params:", grid.best_params_)

# %%
# from sklearn.model_selection import GridSearchCV

# params = {
#     'n_estimators': [100, 200],
#     'max_depth': [3, 6, 9],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'scale_pos_weight': [1, 2, 3]  # useful for imbalance
# }

# grid = GridSearchCV(RandomForestClassifier(), param_grid=params, scoring= "precision", cv=5)
# grid.fit(X_resampled, y_resampled)
# print("best recall: ", grid.best_score_)
# print("params recall: ", grid.best_params_)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, 20],
    "criterion":["gini", "entropy", "log_loss"],
    'min_samples_split': [2, 5],
    'class_weight': ['balanced',"balanced_subsample"],
    "max_features":["sqrt", "log2", None],
    "oob_score":[True,False],
    "bootstrap":[True,False]
}

grids = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=3, scoring='recall')
gridss = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=3, scoring='precision')
gridsss = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=3, scoring='roc_auc')
# grids.fit(x_train, y_train)
grids.fit(X_resampled, y_resampled)
gridss.fit(X_resampled, y_resampled)
gridsss.fit(X_resampled, y_resampled)
print("Best params:", grids.best_params_)
print("Best params:", gridss.best_params_)
print("Best params:", gridsss.best_params_)

# %%
y_proba_rf = rfc.predict_proba(x_test)[:, 1]

# Try a threshold between 0.3 and 0.5
new_threshold = 0.57
y_pred_adjusted = (y_proba_rf >= new_threshold).astype(int)

from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
print(confusion_matrix(y_test, y_pred_adjusted))
print(classification_report(y_test, y_pred_adjusted))
print("ROC AUC:", roc_auc_score(y_test, y_proba_rf))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, roc_curve, auc

# y_test: actual labels
# y_proba: predicted probabilities for class 1 (model.predict_proba(X)[:, 1])

def find_best_threshold(y_test, y_proba):
    precisions, recalls, thresholds = precision_recall_curve(y_test, y_proba)
    
    # Avoid divide-by-zero
    f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-10)
    
    best_idx = np.argmax(f1_scores)
    best_threshold = thresholds[best_idx]
    best_f1 = f1_scores[best_idx]
    
    print(f"Best Threshold: {best_threshold:.4f}")
    print(f"Precision: {precisions[best_idx]:.4f}")
    print(f"Recall: {recalls[best_idx]:.4f}")
    print(f"F1 Score: {best_f1:.4f}")
    
    # Plot Precision-Recall curve
    plt.figure(figsize=(8,5))
    plt.plot(recalls, precisions, label='Precision-Recall Curve')
    plt.scatter(recalls[best_idx], precisions[best_idx], color='red', label='Best Threshold')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend()
    plt.grid(True)
    plt.show()

    # ROC curve
    fpr, tpr, roc_thresholds = roc_curve(y_test, y_proba)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8,5))
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:
# find_best_threshold(y_test, y_proba)

# %%
find_best_threshold(y_test, y_pred1)

# %%
import lightgbm as lgb
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, precision_score, recall_score, f1_score, accuracy_score

# Set scale_pos_weight for imbalance: (Negative samples / Positive samples)
scale_pos_weight = (y_train.value_counts()[0] / y_train.value_counts()[1])

model = lgb.LGBMClassifier(
    boosting_type='gbdt',
    num_leaves=31,
    max_depth=-1,
    learning_rate=0.05,
    n_estimators=1000,
    scale_pos_weight=scale_pos_weight,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=0.1
)

# Train with early stopping
model.fit(
    x_train, y_train,
    eval_set=[(x_test, y_test)],
    eval_metric='auc',
    # early_stopping_rounds=50,
    # verbose=False
)

# Predictions
y_pred = model.predict(x_test)
y_prob = model.predict_proba(x_test)[:,1]

# Metrics
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
print("ROC AUC:", roc_auc_score(y_test, y_prob))
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# [LightGBM] [Info] Number of positive: 1644, number of negative: 6356
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003604 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 856
# [LightGBM] [Info] Number of data points in the train set: 8000, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205500 -> initscore=-1.352267
# [LightGBM] [Info] Start training from score -1.352267
# Confusion Matrix:
#  [[1445  162]
#  [ 145  248]]
# Precision: 0.6048780487804878
# Recall: 0.6310432569974554
# F1 Score: 0.6176836861768369
# ROC AUC: 0.8514688441630209
# Accuracy: 0.8465
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90      1607
#            1       0.60      0.63      0.62       393
#
#     accuracy                           0.85      2000
# ...

# %%
y_pred_proba = model.predict_proba(x_test)[:, 1]
y_pred_custom = (y_pred_proba >= 0.35).astype(int)

# %%
# Metrics
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_custom))
print("Precision:", precision_score(y_test, y_pred_custom))
print("Recall:", recall_score(y_test, y_pred_custom))
print("F1 Score:", f1_score(y_test, y_pred_custom))
print("ROC AUC:", roc_auc_score(y_test, y_prob))
print("Accuracy:", accuracy_score(y_test, y_pred_custom))
print("\nClassification Report:\n", classification_report(y_test, y_pred_custom))
# Out:
# Confusion Matrix:
#  [[1359  248]
#  [ 117  276]]
# Precision: 0.5267175572519084
# Recall: 0.7022900763358778
# F1 Score: 0.6019629225736096
# ROC AUC: 0.8514688441630209
# Accuracy: 0.8175
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88      1607
#            1       0.53      0.70      0.60       393
#
#     accuracy                           0.82      2000
#    macro avg       0.72      0.77      0.74      2000
# weighted avg       0.84      0.82      0.83      2000

# %%
y_pred_proba = model.predict_proba(x_test)[:,1]
threshold = 0.6  # try higher for better precision
y_pred = (y_pred_proba >= threshold).astype(int)
